# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
# TODO
import pandas as pd
import numpy as np
array = np.array(pd.to_numeric(ds['price']))
ind_max = np.nanargmax(array)
objeto = ds.iloc[ind_max]
precio = objeto.get("price")
lugar = objeto.get("address")
print(f"La casa con dirección en {lugar} es la mas cara y su precio es de {precio}")
# Out:
# La casa con dirección en El Escorial es la mas cara y su precio es de 8500000

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
# TODO
filtrado = ds[ds['price'] != 0]
array = np.array(pd.to_numeric(filtrado['price']))
ind_min = np.nanargmin(array)
objeto = filtrado.iloc[ind_min]
precio = objeto.get("price")
lugar = objeto.get("address")
print(f"La casa con dirección en {lugar} es la mas barata y su precio es de {precio}")
# Out:
# La casa con dirección en Berlin, Coslada es la mas barata y su precio es de 600

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
# TODO
array = np.array(pd.to_numeric(ds['surface']))
ind_max = np.nanargmax(array)
ind_min = np.nanargmin(array)
objeto_max = ds.iloc[ind_max]
objeto_min = ds.iloc[ind_min]
lugar_max = objeto_max.get('address')
lugar_min = objeto_min.get('address')
sup_max = objeto_max.get("surface")
sup_min = objeto_min.get('surface')
print(f"La casa mas grande esta ubicada en {lugar_max} y su superficie es de {sup_max}")
print(f"La casa mas pequeña esta ubicada en {lugar_min} y su superficie es de {sup_min}")
# Out:
# La casa mas grande esta ubicada en Sevilla la Nueva y su superficie es de 249000.0
# La casa mas pequeña esta ubicada en Calle Amparo,  Madrid Capital y su superficie es de 15.0

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
# TODO
array = np.array(ds["level5"])
filtro = np.unique(array)
print(', '.join(filtro))
# Out:
#  Madrid Capital, Ajalvir, Alcalá de Henares, Alcobendas, Alcorcón, Aldea del Fresno, Algete, Alpedrete, Ambite, Anchuelo, Aranjuez, Arganda del Rey, Arroyomolinos (Madrid), Batres, Becerril de la Sierra, Belmonte de Tajo, Boadilla del Monte, Braojos, Brea de Tajo, Brunete, Buitrago del Lozoya, Bustarviejo, Cabanillas de la Sierra, Cadalso de los Vidrios, Camarma de Esteruelas, Campo Real, Canencia, Carabaña, Casarrubuelos, Cenicientos, Cercedilla, Chapinería, Chinchón, Ciempozuelos, Cobeña, Collado Mediano, Collado Villalba, Colmenar Viejo, Colmenar de Oreja, Colmenar del Arroyo, Colmenarejo, Corpa, Coslada, Cubas de la Sagra, Daganzo de Arriba, El Atazar, El Berrueco, El Boalo - Cerceda – Mataelpino, El Escorial, El Molar (Madrid), El Vellón, El Álamo, Estremera, Fresnedillas de la Oliva, Fresno de Torote, Fresno de Torote - Serracines, Fuenlabrada, Fuente El Saz de Jarama, Fuentidueña de Tajo, Galapagar, Garganta de los Montes, Gargantilla del Lozoya, Gascones, Getafe, Griñón, Guad
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
# TODO
posicion = ds.isna()
for fi_ind, fila in posicion.iterrows():
    for col_ind, is_nan in enumerate(fila):
        if is_nan:
            print(f"NAs encontrado en {fi_ind}/{ds.columns[col_ind]}")

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
# TODO
original = ds.shape
#aplicar un valor desconocido al Na
#unk = ds.fillna("Unknown")
filtro = ds.dropna() 
shape_fil = filtro.shape
print(f"Dimensiones sin limpiar: {original}")
print(f"Dimensiones despues de limpiar: {shape_fil}")
# Out:
# Dimensiones sin limpiar: (15335, 37)
# Dimensiones despues de limpiar: (0, 37)

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
# TODO
array = ds[ds['level5'] == "Arroyomolinos (Madrid)"]
media = array['price'].mean()
print(media)
# Out:
# 294541.59854014596

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
# TODO: Code
import matplotlib.pyplot as plt
ds = pd.read_csv('assets/real_estate.csv', sep=';')
array = ds[ds['level5'] == "Arroyomolinos (Madrid)"]
plt.figure(figsize=(10,5))
plt.hist(array['price'], bins=10, color='gray', edgecolor='black')
plt.title("Histograma de Precios en Arroyomolinos (Madrid)")
plt.xlabel("Precio")
plt.ylabel("Frecuencia")
plt.grid(False)
plt.show()

# %% [markdown]
# Se observa como la mayoría de las viviendas se concentran en un rango en particular, lo que indica una tendencia a precios mas "accesibles" en comparación a los valores que se encuentran fuera que indican propiedades mas costosas en menor cantidad, y algunas en "0" que podrían ser error de la Base de Datos

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
# TODO
array1 = ds[ds['level5'] == "Valdemorillo"]
array2 = ds[ds['level5'] == "Galapagar"]
promedio1 = array1['price'].mean()
promedio2 = array2['price'].mean()
print(promedio1)
print(promedio2)
# Out:
# 363860.2931034483
# 360063.20238095237

# %% [markdown]
# Aunque los promedios no son iguales, estan bastante cercanos uno del otro lo que indica similitud de precios en estas localidades.

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
# TODO
ds['pps'] = ds['price'] / ds['surface']
array1 = ds[ds['level5'] == "Valdemorillo"]
array2 = ds[ds['level5'] == "Galapagar"]
promedio1 = array1['pps'].mean()
promedio2 = array2['pps'].mean()
print(promedio1)
print(promedio2)
# Out:
# 1317.9502109024986
# 1606.3240303094024

# %% [markdown]
# Los promedios de pps no son los mismos, y se observa que Galapagar tiene un precio promedio significativamente mas alto, lo que indica que estas pueden ser percibidas como mas valiosas que las de Valdemorillo

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
# TODO: Código
ds = pd.read_csv('assets/real_estate.csv', sep=';')
plt.figure(figsize=(10,5))
plt.scatter(ds['surface'], ds['price'], color='gray', edgecolor='black')
plt.title("Relación entre Superficie y Precio")
plt.xlabel("Superficie (m²)")
plt.ylabel("Precio (€)")
plt.grid(False)
plt.show()

# %% [markdown]
# Existe una propiedad con superficie atípica que podría ser legítimo pero afecta la visualización del gráfico, esta se podría filtrar para observar la relación entre superficie y precios

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
# TODO
agencias = ds['realEstate_name'].nunique()
print(f'El dataset contiene {agencias} agencias de bienes raices únicas')
# Out:
# El dataset contiene 1821 agencias de bienes raices únicas

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
# TODO
pobl = ds['level5'].value_counts()
masc = pobl.max()
masp = pobl.idxmax()
print(f"La poblacion con mayor cantidad de casas es {masp} y tiene {masc} casas")
# Out:
# La poblacion con mayor cantidad de casas es  Madrid Capital y tiene 6643 casas

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
# TODO
cinturon_sur_poblaciones = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]
cinturon_sur_df = ds[ds['level5'].isin(cinturon_sur_poblaciones)]
print(cinturon_sur_df)

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
# TODO: Code
mediana_cs = cinturon_sur_df.groupby('level5')['price'].median()
plt.figure(figsize=(10,5))
mediana_cs.plot(kind='bar', color='gray', edgecolor='black')
plt.title('Mediana de Precios en el Cinturón Sur de Madrid')
plt.xlabel('Población')
plt.ylabel('Mediana de Precio (€)')
plt.grid(False)
plt.show()

# %% [markdown]
# Observamos como en el cinturon sur de Madrid la mediana de precio de las poblaciones estan en un rango similar exceptuando la población de Getafe que está significativamente por encima de las demás

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
# TODO
variables = ['price', 'rooms', 'surface', 'bathrooms']
for v in variables:
    promedio = cinturon_sur_df[v].mean()
    varianza = cinturon_sur_df[v].var()
    print(f"Nombre: {v} / Promedio: {promedio} / Varianza: {varianza}")
# Out:
# Nombre: price / Promedio: 223094.48070562293 / Varianza: 14921367508.04902
# Nombre: rooms / Promedio: 3.0177383592017737 / Varianza: 0.7188858892927542
# Nombre: surface / Promedio: 111.75222363405337 / Varianza: 4263.051760316337
# Nombre: bathrooms / Promedio: 1.633221850613155 / Varianza: 0.5717968625577321

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
# TODO
casamasc = cinturon_sur_df.loc[cinturon_sur_df.groupby('level5')['price'].idxmax()]
print(casamasc[['address', 'price', 'level5']])
# Out:
#                                      address    price       level5
# 5585                                Alcorcón   950000     Alcorcón
# 11561  Calle de Paulo Freire, 5, Fuenlabrada   490000  Fuenlabrada
# 2881                                  Getafe  1050000       Getafe
# 10412           Avenida Reina Sofía, Leganés   650000      Leganés

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
# TODO
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
dict = {}
for pob in cinturon_sur_poblaciones:
    data = cinturon_sur_df[cinturon_sur_df['level5'] == pob]
    normalizado = scaler.fit_transform(data[['price']])
    dict[pob] = normalizado.flatten()

plt.figure(figsize=(10, 6))
for pob in cinturon_sur_poblaciones:
    plt.hist(dict[pob], bins=10, alpha=0.5, label=pob)
plt.title("Histogramas de Precios Normalizados en el Cinturón Sur de Madrid")
plt.xlabel("Precio Normalizado")
plt.ylabel("Frecuencia")
plt.legend(loc="upper right")
plt.grid(False)

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
# TODO
cinturon_sur_df.loc[:, 'pps'] = cinturon_sur_df['price'] / cinturon_sur_df['surface']
getafe = cinturon_sur_df[cinturon_sur_df['level5'] == 'Getafe']
alcorcon = cinturon_sur_df[cinturon_sur_df['level5'] == 'Alcorcón']
media_getafe = getafe['pps'].mean()
media_alcorcon = alcorcon['pps'].mean()
print(f"Precio medio por metro cuadrado en Getafe: {media_getafe}")
print(f"Precio medio por metro cuadrado en Alcorcón: {media_alcorcon}")
# Out:
# Precio medio por metro cuadrado en Getafe: 2066.314949251463
# Precio medio por metro cuadrado en Alcorcón: 2239.302480199618

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
# TODO
fig, axs = plt.subplots(2, 2, figsize=(10, 6))
for i, poblacion in enumerate(cinturon_sur_poblaciones):
    data = cinturon_sur_df[cinturon_sur_df['level5'] == poblacion]
    row, col = divmod(i, 2)
    axs[row, col].scatter(data['surface'], data['price'], alpha=0.5)
    axs[row, col].set_title(f'{poblacion}')
    axs[row, col].set_xlabel('Superficie (m²)')
    axs[row, col].set_ylabel('Precio (€)')
    axs[row, col].grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps

# Mapa centrado en (60 grados latitud y -2.2 grados longitud)
# Latitud, longitud
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.OpenStreetMap.Mapnik)

# %%
## Aquí: traza la coordenadas de los estados

## PON TU CÓDIGO AQUÍ:
from ipyleaflet import Marker, AwesomeIcon
cinturon_sur_df['latitude'] = pd.to_numeric(cinturon_sur_df['latitude'])
cinturon_sur_df['longitude'] = pd.to_numeric(cinturon_sur_df['longitude'])
coordenadas = {}
for poblacion in cinturon_sur_poblaciones:
    data = cinturon_sur_df[cinturon_sur_df['level5'] == poblacion]
    coordenadas[poblacion] = list(zip(data['latitude'], data['longitude']))
colores = {
    "Fuenlabrada": 'gray',
    "Leganés": 'red',
    "Getafe": 'green',
    "Alcorcón": 'blue'
}
for poblacion, coord_list in coordenadas.items():
    for coord in coord_list:
        icono = AwesomeIcon(name='info-sign', marker_color=colores[poblacion], icon_color='white')
        marcador = Marker(location=coord, draggable=False, icon=icono)
        map.add_layer(marcador)

map
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_24072\645864756.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cinturon_sur_df['latitude'] = pd.to_numeric(cinturon_sur_df['latitude'])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_24072\645864756.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cinturon_sur_df['longitude'] = pd.to_numeric(cinturon_sur_df['longitude'])
# Map(bottom=791249.0, center=[40.35269287243362, -3.7861633300781254], controls=(ZoomControl(options=['position…
